# %%
from sympy import *
from sympy import Poly
print("> Imported successfully")
m1, m2 = symbols('m1, m2')
a, b, c, d, x, y, z, t = symbols('a, b, c, d, x, y, z, t')
# Out:
# > Imported successfully

# %%
f=m1*(a**3+b**3+c**3+0*d**3) - m2*(a**5+b**5+c**5+0*d**5)

# %%
f
# Out:
# m1*(a**3 + b**3 + c**3) - m2*(a**5 + b**5 + c**5)

# %%
# f.subs({a: t, b: t, c: t, d: 4 - 3*t})
f.subs({a: t, b: t, c: 3-2*t})
# Out:
# m1*(2*t**3 + (3 - 2*t)**3) - m2*(2*t**5 + (3 - 2*t)**5)

# %%
_.factor()
# Out:
# 3*(-2*m1*t**3 + 12*m1*t**2 - 18*m1*t + 9*m1 + 10*m2*t**5 - 80*m2*t**4 + 240*m2*t**3 - 360*m2*t**2 + 270*m2*t - 81*m2)

# %%
collect(_, t)
# Out:
# 27*m1 + 30*m2*t**5 - 240*m2*t**4 - 243*m2 + 3*t**3*(-2*m1 + 240*m2) + 3*t**2*(12*m1 - 360*m2) + 3*t*(-18*m1 + 270*m2)

# %%
_,primitive(factor(Poly(_, t).discriminant()))
# Out:
# (27*m1 + 30*m2*t**5 - 240*m2*t**4 - 243*m2 + 3*t**3*(-2*m1 + 240*m2) + 3*t**2*(12*m1 - 360*m2) + 3*t*(-18*m1 + 270*m2),
#  (127545840,
#   -16*m1**7*m2 + 2080*m1**6*m2**2 - 34344*m1**5*m2**3 + 241155*m1**4*m2**4 - 1042500*m1**3*m2**5 + 2504250*m1**2*m2**6 - 3037500*m1*m2**7 + 1366875*m2**8))

# %%
# ct, pt = primitive(_)

# %%
# factor(pt)
