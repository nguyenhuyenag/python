# %%
from sympy import *
print("> Imported successfully")
a, b, c, d, x, y, z, t = symbols('a, b, c, d, x, y, z, t')
# Out:
# > Imported successfully

# %%
# f = 1/(1+a**2)+1/(1+b**2)-2/(1+a*b)

# %%
f = 1/(a+1)**2 + 1/(b+1)**2 - 1/(1+a*b)

# %%
factor(f)
# Out:
# (a**3*b - a**2*b**2 + a*b**3 - 2*a*b + 1)/((a + 1)**2*(b + 1)**2*(a*b + 1))

# %%
(a/b+1)*(a*b+1)
# Out:
# (a/b + 1)*(a*b + 1)

# %%
factor(_)
# Out:
# (a + b)*(a*b + 1)/b

# %%
1/_
# Out:
# b/((a + b)*(a*b + 1))

# %%
denom(_)
# Out:
# (a + b)*(a*b + 1)
