# %%
from sympy import *
print("> Imported successfully")
a, b, c, d, x, y, z, t = symbols('a, b, c, d, x, y, z, t')
# Out:
# > Imported successfully

# %%
f = 1/a + 1/b + 1/c - 3 - Rational(27, 100)*(a**3 + b**3 + c**3 - 3)

# %%
f
# Out:
# -27*a**3/100 - 27*b**3/100 - 27*c**3/100 - 219/100 + 1/c + 1/b + 1/a

# %%
f.subs({a: t, b: t, c: 3 - 2*t})
# Out:
# -27*t**3/50 - 27*(3 - 2*t)**3/100 - 219/100 + 1/(3 - 2*t) + 2/t

# %%
_.factor()
# Out:
# 3*(t - 1)**2*(3*t - 2)**2*(6*t - 25)/(50*t*(2*t - 3))

# %%
f1 = f.factor()
f1
# Out:
# -(27*a**4*b*c + 27*a*b**4*c + 27*a*b*c**4 + 219*a*b*c - 100*a*b - 100*a*c - 100*b*c)/(100*a*b*c)

# %%
numer(f1), denom(f1)
# Out:
# (-27*a**4*b*c - 27*a*b**4*c - 27*a*b*c**4 - 219*a*b*c + 100*a*b + 100*a*c + 100*b*c,
#  100*a*b*c)

# %%
f1.as_numer_denom()
# Out:
# (-27*a**4*b*c - 27*a*b**4*c - 27*a*b*c**4 - 219*a*b*c + 100*a*b + 100*a*c + 100*b*c,
#  100*a*b*c)

# %%
f = (4*a**2+(a+b+c)**2)*(b+c) - 4*(a*b*(a+b)+b*c*(b+c)+c*a*(c+a))
